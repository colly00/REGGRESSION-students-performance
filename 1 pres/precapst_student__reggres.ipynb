# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
# Load dataset
df = pd.read_csv(r'C:\Users\TFC\Downloads\student_habits_performance.csv')
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# CLEANING DATA

# %%
# Drop ID column
df.drop('student_id', axis =1, inplace=True)
df.drop('age', axis =1, inplace=True)
df.drop('diet_quality', axis =1, inplace=True)
df.drop('exercise_frequency', axis =1, inplace=True)
df.drop('parental_education_level', axis =1, inplace=True)
df.drop('internet_quality', axis =1, inplace=True)
df.drop('mental_health_rating', axis =1, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
cat= df.select_dtypes('object')
num= df.select_dtypes('number')

# %%
cat
# Out:
#      gender part_time_job extracurricular_participation
# 0    Female            No                           Yes
# 1    Female            No                            No
# 2      Male            No                            No
# 3    Female            No                           Yes
# 4    Female            No                            No
# ..      ...           ...                           ...
# 995  Female            No                           Yes
# 996  Female           Yes                           Yes
# 997    Male            No                           Yes
# 998    Male           Yes                            No
# 999  Female            No                            No
#
# [1000 rows x 3 columns]

# %%
num
# Out:
#      study_hours_per_day  social_media_hours  netflix_hours  \
# 0                    0.0                 1.2            1.1
# 1                    6.9                 2.8            2.3
# 2                    1.4                 3.1            1.3
# 3                    1.0                 3.9            1.0
# 4                    5.0                 4.4            0.5
# ..                   ...                 ...            ...
# 995                  2.6                 0.5            1.6
# 996                  2.9                 1.0            2.4
# 997                  3.0                 2.6            1.3
# 998                  5.4                 4.1            1.1
# 999                  4.3                 2.9            1.9
#
#      attendance_percentage  sleep_hours  exam_score
# 0                     85.0          8.0        56.2
# 1                     97.3          4.6       100.0
# 2                     94.8          8.0        34.3
# ...

# %% [markdown]
# UNIVAIRETE ANALYSIS

# %%
for column in cat.columns:
    sns.countplot(x=cat[column])
    plt.title(f'Bar Plot of {column}')
    plt.show()

# %%
for column in num.columns:
    sns.boxplot(x=num[column])
    plt.title(f'Bar Plot of {column}')
    plt.show()

# %% [markdown]
# BIVIRETE ANALYSIS

# %%
for col in num.columns:
    df['binned']= pd.cut(df[col],bins=4)
    sns.barplot(data=df, y='exam_score', x='binned')
    plt.title(f'Exam Score vs {col} (binned)')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\TFC\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\TFC\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ...

# %%
for col in cat.columns:
    sns.barplot(y='exam_score', x=cat[col], data=df)
    plt.xticks(rotation=45)
    plt.show()

# %%
df.drop('binned', axis =1, inplace=True)

# %%
# Encode all categorical (object) columns into numeric
from sklearn.preprocessing import LabelEncoder, StandardScaler
label_encoders = {}
for col in df.select_dtypes(include="object").columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df
# Out:
#      gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0         0                  0.0                 1.2            1.1
# 1         0                  6.9                 2.8            2.3
# 2         1                  1.4                 3.1            1.3
# 3         0                  1.0                 3.9            1.0
# 4         0                  5.0                 4.4            0.5
# ..      ...                  ...                 ...            ...
# 995       0                  2.6                 0.5            1.6
# 996       0                  2.9                 1.0            2.4
# 997       1                  3.0                 2.6            1.3
# 998       1                  5.4                 4.1            1.1
# 999       0                  4.3                 2.9            1.9
#
#      part_time_job  attendance_percentage  sleep_hours  \
# 0                0                   85.0          8.0
# ...

# %%
from sklearn.model_selection import train_test_split

# Define features (X) and target (y)
X = df.drop('exam_score', axis=1)
y = df['exam_score']

# Split data: 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30 )

# %%
# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Initialize and train the model
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_test_scaled)
# Predict on test set

# %%
# Evaluate the model
rmse = mean_squared_error(y_test, y_pred, squared=False)
lr_rmse_percent=(rmse/np.mean(y_test))*100
r2 = r2_score(y_test, y_pred)

print(f"Root Mean Squared Error (RMSE):{lr_rmse_percent:.2f}")
print(f"R2 Score: {r2:.2f}")
# Out:
# Root Mean Squared Error (RMSE):11.16
# R2 Score: 0.81

# %%
import joblib
joblib.dump(model,'precapst_1.joblib' )
# Out:
# ['precapst_1.joblib']

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\TFC

# %% [markdown]
# DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Initialize and train the model
dt = DecisionTreeRegressor(random_state=42)
dt.fit(X_train_scaled, y_train)
y_pred_dt = dt.predict(X_test_scaled)
# Predict only on test set (important!)

# %%
dt_rmse = mean_squared_error(y_test, y_pred_dt)
dt_rmse_percent=(dt_rmse/np.mean(y_test))*100
r2_dt = r2_score(y_test, y_pred_dt)

# Evaluate

# %%
#print result
print("Decision Tree Regressor")
print("RMSE", dt_rmse)
print(f"R2 Score:", r2_dt)
# Out:
# Decision Tree Regressor
# RMSE 160.37135
# R2 Score: 0.4950597024258414

# %% [markdown]
# RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train_scaled, y_train)
# Initialize and train the model
y_pred_rf = rf.predict(X_test_scaled)
# Predict on test set

# %%
rf_rmse = np.sqrt(mean_squared_error(y_test, y_pred_rf))
rf_rmse_percent=(rf_rmse/np.mean(y_test))*100
r2_rf= r2_score(y_test, y_pred_rf)
# Evaluate

# %%
#print result
print("Random Forest Regressor")
print("RMSE",rf_rmse_percent)
print(f"R2 Score:", r2_rf)
# Out:
# Random Forest Regressor
# RMSE 12.160079839185974
# R2 Score: 0.7732270945203656

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVR
svm = SVR()
svm.fit(X_train_scaled, y_train)
# Initialize and train the model
y_pred_svm= svm.predict(X_test_scaled)
# Predict on test set

# %%
svm_rmse =np.sqrt(mean_squared_error(y_test, y_pred_svm))
rmse_percent=(svm_rmse/np.mean(y_test))*100
r2_svm= r2_score(y_test, y_pred_svm)
# Evaluate

# %%
#print result
print("SVM Regressor")
print(f'RMSE: {rmse_percent:.2f}')
print(f'RMSE as % of mean:{rmse_percent:}.2f%')
print(f"R2 Score:", r2_svm)
# Out:
# SVM Regressor
# RMSE: 14.80
# RMSE as % of mean:14.80403355412295.2f%
# R2 Score: 0.6638923222821862

# %%
from sklearn.linear_model import LassoCV
lasso = LassoCV(cv=5, random_state=42)
lasso.fit(X_train_scaled, y_train)

# Get feature importance
importance = pd.Series(lasso.coef_, index=X_train.columns)
importance_sorted = importance.sort_values(ascending=False)

print("\n🧠 Feature Importance from LassoCV:")
print(importance_sorted)

# Optionally: visualize
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
importance_sorted.plot(kind='barh')
plt.title("Feature Importance (Lasso)")
plt.xlabel("Coefficient Weight")
plt.tight_layout()
plt.show()
# Out:
# 🧠 Feature Importance from LassoCV:
# study_hours_per_day              13.569426
# sleep_hours                       2.279995
# attendance_percentage             1.149524
# gender                            0.279349
# extracurricular_participation     0.008790
# part_time_job                     0.000000
# netflix_hours                    -2.310969
# social_media_hours               -3.037218
# dtype: float64
